# %% [markdown]
# # Python - Modules & Packages

# %% [markdown]
# ## Modules

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
from random import randint
from random import *

# %%
import numpy
numpy.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
#using alaias
import numpy as np
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
dir(np)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
help(np.zeros)
# Out:
# Help on built-in function zeros in module numpy:
#
# zeros(shape, dtype=None, order='C', *, device=None, like=None)
#     zeros(shape, dtype=None, order='C', *, device=None, like=None)
#
#     Return a new array of given shape and type, filled with zeros.
#
#     Parameters
#     ----------
#     shape : int or tuple of ints
#         Shape of the new array, e.g., ``(2, 3)`` or ``2``.
#     dtype : data-type, optional
#         The desired data-type for the array, e.g., `numpy.int8`.  Default is
#         `numpy.float64`.
#     order : {'C', 'F'}, optional, default: 'C'
#         Whether to store multi-dimensional data in row-major
#         (C-style) or column-major (Fortran-style) order in memory.
#     device : str, optional
#         The device on which to place the created array. Default: ``None``.
#         For Array-API interoperability only, so must be ``"cpu"`` if passed.
#
#         .. versionadded:: 2.0.0
#     like : array_like, optional
# ...

# %% [markdown]
# ## Exersise

# %% [markdown]
# Q1. Explore contents of math module , exp,floor,ceil,log,factorial

# %%
print(math.floor(2.8)) #round down
print(math.ceil(2.8)) #round up
# Out:
# 2
# 3

# %%
import random
random.seed(1)
print("random in first run is --->",random.randint(1,10))
print("random in Second run is --->",random.randint(1,10))
print("random in third run is --->",random.randint(1,10))
# Out:
# random in first run is ---> 3
# random in Second run is ---> 10
# random in third run is ---> 2

# %%
import random
random.seed(10)
print("random in first run is --->",random.randint(1,10))
print("random in Second run is --->",random.randint(1,10))
print("random in third run is --->",random.randint(1,10))
# Out:
# random in first run is ---> 10
# random in Second run is ---> 1
# random in third run is ---> 7

# %% [markdown]
# # Data types

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
True
# Out:
# True

# %%
x = 3
x > 3
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
int(0.01)
# Out:
# 0

# %%
type(5 + 2.8 - 3)
# Out:
# float

# %% [markdown]
# # Python - Variables,Expression & statements

# %%
x = 3

# %%
_x = 4
print(_x)
# Out:
# 4

# %%
Same = 5
same = 4
SaMe = 10
#they are not same

# %%
#statement could be doing some assignments, printing something or running loops or decision 
print("statements")
# Out:
# statements

# %%
#compound statements loops ,conditions : is ,or ,and ,not

# %%
#expression: +,-,*,%,//,*()
x + 3 - 9
# Out:
# -3

# %%
((10+2)-(11))*2
# Out:
# 2

# %%
str1 = "dev"
str2 = "_spec"
newstr=str1 + str2
newstr*3
# Out:
# 'dev_specdev_specdev_spec'

# %%
5%2 #reminder
# Out:
# 1

# %%
5//2 #quotient
# Out:
# 2

# %%
5/2 #real number
# Out:
# 2.5

# %%
-5//2 #floored
# Out:
# -3

# %%
x=10
y=5
x = x + 1
y+=5

print(x,y)
# Out:
# 11 10
