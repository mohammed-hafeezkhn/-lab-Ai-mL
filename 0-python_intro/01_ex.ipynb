# %% [markdown]
# # Python - OUTPUT Statements

# %%
print("Hello World from Python!")
# Out:
# Hello World from Python!

# %%
print("3+4 = =",3+4)
# Out:
# 3+4 = = 7

# %% [markdown]
# SYNTAX
#
# print("Write things to display")

# %%
print('this','is','the','first',sep="=")
# Out:
# this=is=the=first

# %%
print('this','is',"first",end="+")
# Out:
# this is first+

# %%
print("first line \nsecond line")
# Out:
# first line
# second line

# %% [markdown]
# # Exersise

# %% [markdown]
# Q.1 print triangle like below

# %%
#*
#**
#***
#****
#*****

# %% [markdown]
# Q2. print triangle of following type

# %%
#   *
#  **
# ***
#****

print(i*"*")
# Out:
# **
