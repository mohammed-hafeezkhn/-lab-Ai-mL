# %% [markdown]
# # Input Statements

# %%
name = input("whats your name ")
print(name)
# Out:
# human

# %%
type(name)
# Out:
# str

# %%
Age = int(input("enter your age"))
print(Age)
type(Age)
# Out:
# 28
# int

# %%
Eval1 = eval(input("Enter a number"))
print(Eval1)
type(Eval1)
# Out:
# 31
# int

# %%
float(21)
# Out:
# 21.0

# %%
Basic = eval(input("Enter Salary"))
HRA = Basic *0.01
A = 1500
Total_salary = Basic + HRA + A
print("Total Salary =",Total_salary)
# Out:
# Total Salary = 24730.0

# %% [markdown]
# # Exersise

# %%
#Q1. Square and cube of number 
#print(2^3) gives 1?

N=int(input("n"))
print("square=",N*N)
print("cube=",N**3)
# Out:
# square= 4
# cube= 8
